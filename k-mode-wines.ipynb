# %%
import numpy as np
import pandas as pd
from kmodes.kmodes import KModes
import matplotlib.pyplot as plt

# random categorical data
columns = ["class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium", "Total phenols", "Flavanoids", "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline"]
df = pd.read_csv("./wine.data",index_col=False, names = columns)

X = df.drop('class', 1)
X.head()
y = df['class']
km = KModes(n_clusters=3, verbose=1)

clusters = km.fit_predict(X)

# Print the cluster centroids
print(km.cluster_centroids_)

plt.scatter(X.iloc[:,0],X.iloc[:,1], c=y, cmap='viridis')

centroids = km.cluster_centroids_
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', alpha=0.5)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 14, cost: 2119.0
# Run 1, iteration: 2/100, moves: 0, cost: 2119.0
# [[1.208e+01 1.670e+00 2.300e+00 2.100e+01 8.800e+01 2.200e+00 2.650e+00
#   2.600e-01 1.350e+00 2.600e+00 1.040e+00 2.780e+00 5.200e+02]
#  [1.237e+01 1.730e+00 2.120e+00 1.900e+01 8.000e+01 1.650e+00 2.030e+00
#   3.700e-01 1.460e+00 3.400e+00 1.120e+00 3.170e+00 5.100e+02]
#  [1.383e+01 1.350e+00 2.700e+00 2.000e+01 9.400e+01 2.740e+00 2.920e+00
#   3.200e-01 1.660e+00 2.650e+00 9.600e-01 3.260e+00 6.800e+02]]
